# %%
import pandas as pd
import numpy as np
import gmaps as gm
import datetime 
from sklearn import linear_model
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("C:/Users/melis/Downloads/res.csv", sep=",") #Leer el archivo
df["attributes.date_debut"] = [datetime.datetime.fromtimestamp(i /1000) for i in df["attributes.date_debut"]]
df["attributes.date_fin"] = [datetime.datetime.fromtimestamp(i /1000) for i in df["attributes.date_fin"]]

# %%
year = int(input("Year: "))
month = int(input("Month: "))
day = int(input("Day: "))
hour = int(input ("Hour: "))
date = datetime.datetime(year,month,day,hour)
# Out:
# Year: 2021
# Month: 02
# Day: 02
# Hour: 5

# %%
gm.configure(api_key="AIzaSyBwZMM6oAj8OndeB8wASvQd-xh4xjfoedE")

# %%
df=df.loc[df['attributes.valeur']>=0] #Only positive values
df.reset_index(drop=True, inplace=True) #Reset index after removing the outliers

# %%
df
# Out:
#         attributes.nom_dept attributes.code_station  \
# 0             HAUTE-GARONNE                 FR50021
# 1             HAUTE-GARONNE                 FR50030
# 2             HAUTE-GARONNE                 FR50060
# 3           HAUTES-PYRENEES                 FR50052
# 4                   AVEYRON                 FR50815
# ...                     ...                     ...
# 190640        HAUTE-GARONNE                 FR50043
# 190641        HAUTE-GARONNE                 FR50030
# 190642        HAUTE-GARONNE                 FR50040
# 190643  PYRENEES-ORIENTALES                 FR50802
# 190644                 TARN                 FR50026
#
#                     attributes.nom_station attributes.nom_com  \
# 0                  Toulouse-Mazades Urbain           TOULOUSE
# 1                Toulouse-Berthelot Urbain           TOULOUSE
# 2              Montauban - Ramierou Urbain              MURET
# 3                      Tarbes-Dupuy Urbain             TARBES
# 4                   Rodez - Camonil Urbain              RODEZ
# ...                                    ...                ...
# 190640             Blagnac Aéroport Piste             BLAGNAC
# 190641           Toulouse-Berthelot Urbain           TOULOUSE
# 190642  Toulouse-SETMI Chapitre Industriel           TOULOUSE
# 190643                    Bolquère - rural           BOLQUERE
# 190644                         Albi Urbain               ALBI
#
#        attributes.date_debut attributes.date_fin attributes.nom_poll  \
# 0        2020-11-12 18:00:00 2020-11-12 19:00:00                PM10
# 1        2020-11-12 18:00:00 2020-11-12 19:00:00                PM10
# 2        2020-11-12 18:00:00 2020-11-12 19:00:00                PM10
# 3        2020-11-12 18:00:00 2020-11-12 19:00:00                PM10
# 4        2020-11-12 18:00:00 2020-11-12 19:00:00                PM10
# ...                      ...                 ...                 ...
# 190640   2021-03-04 08:00:00 2021-03-04 09:00:00                PM10
# 190641   2021-03-04 09:00:00 2021-03-04 10:00:00                PM10
# 190642   2021-03-04 07:00:00 2021-03-04 08:00:00                PM10
# 190643   2021-03-04 07:00:00 2021-03-04 08:00:00                PM10
# 190644   2021-03-04 09:00:00 2021-03-04 10:00:00                PM10
#
#         attributes.valeur  geometry.x  geometry.y
# 0                    19.7    1.438610     43.6236
# 1                    20.5    1.444030     43.5873
# 2                    41.3    1.375310     44.0129
# 3                    15.7    0.062222     43.2303
# 4                    14.4    2.570700     44.3570
# ...                   ...         ...         ...
# 190640               33.5    1.377250     43.6253
# 190641               39.5    1.444030     43.5873
# 190642               35.3    1.403920     43.5564
# 190643              155.1    2.079500     42.5039
# 190644               40.1    2.146110     43.9281
#
# [190645 rows x 10 columns]

# %%
locations = df.iloc[df.loc[(df["attributes.nom_poll"] == "PM10") & (df["attributes.date_debut"] == date)].index,[9,8]]
weights = df.iloc[df.loc[(df["attributes.nom_poll"] == "PM10") & (df["attributes.date_debut"] == date)].index,7]
fig = gm.figure()
fig.add_layer(gm.heatmap_layer(locations, weights=weights))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
